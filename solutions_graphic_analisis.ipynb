# %%
import solutions
import graph
import solutions_analisis

# %% [markdown]
# # Analisis de la solución optima

# %% [markdown]
# ## Analisis de rendimiento de nuestra solución

# %%
df_time = solutions_analisis.get_execution_time(solutions.get_optimal_analisis_order, max=400, rep=100)
df_time
# Out:
#          time
# 2    0.009739
# 3    0.010696
# 4    0.012419
# 5    0.013276
# 6    0.014080
# ..        ...
# 395  0.848905
# 396  0.853674
# 397  0.865068
# 398  0.855792
# 399  0.861826
#
# [398 rows x 1 columns]

# %%
graph.make_execution_time_graph(df_time)

# %% [markdown]
# ## Analisis con los dataset de la catedra

# %%
catedra_test_files=['3-elem.txt','10-elem.txt','100-elem.txt','10000-elem.txt']
catedra_test_path = ["./casos_prueba_catedra/"+ file for file in catedra_test_files] 

catedra_duration_results = solutions_analisis.catedra_data_sets_analysis(catedra_test_path)

catedra_duration_results
# Out:
#         solution  our proposal  alternative     random
# 3             10            10           17         12
# 10            29            29           37         30
# 100         5223          5223         5313       5257
# 10000  497886735     497886735    497986614  497922030

# %%
graph.make_graph_for_different_method_durations(catedra_duration_results, "solution", "data sets de la catedra")

# %% [markdown]
# ## Analisis con datasets propios

# %%
test_files=[str(n) + '-elem.txt' for n in range(3, 11)]
test_path = ["./casos_prueba/"+ file for file in test_files] 

(homemade_durations_results, homemade_execution_time_results, brute_force_discrepancies) = solutions_analisis.homemade_data_sets_analysis(test_path)

# %% [markdown]
# ### Analisis con diferentes metodos

# %%
homemade_durations_results
# Out:
#     our proposal  brute_force  alternative  random
# 3             27           27           32      32
# 4             34           34           42      35
# 5             51           51           57      57
# 6             73           73           83      80
# 7             75           75           89      87
# 8             54           54           69      67
# 9             86           86          103      86
# 10           108          108          122     112

# %%
graph.make_graph_for_different_method_durations(homemade_durations_results, "brute_force", "data sets propios")

# %% [markdown]
# ### Analisis frente a fuerza bruta

# %% [markdown]
# ### Analisis de soluciones

# %%
own_solution = brute_force_discrepancies[2]["our proposal"]
brute_force_solution = brute_force_discrepancies[2]["brute_force"]
graph.make_graph_from_analisis_order(own_solution, "Gráfico de orden óptimo con algoritmo propio")
graph.make_graph_from_analisis_order(brute_force_solution, "Gráfico de orden óptimo con algoritmo fuerza bruta")

# %% [markdown]
# #### Analisis de rendimiento

# %%
homemade_execution_time_results
# Out:
#     our proposal  brute_force
# 3            0.0     0.000000
# 4            0.0     0.000000
# 5            0.0     0.000000
# 6            0.0     0.000000
# 7            0.0     3.996611
# 8            0.0    77.780724
# 9            0.0   470.419884
# 10           0.0  4861.492157

# %%
graph.make_execution_time_graph(homemade_execution_time_results, "Gráfico de tiempo de ejecucion optimo vs fuerza bruta")
